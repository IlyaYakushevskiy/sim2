# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
from simulation_modul import *
rng = np.random.default_rng(42)

# %% [markdown]
# # 1) Partition function and tree build
#
# - Implement a particle class and a cell class
# - Implement the partitioning of particles function we introduced in class.
# - The hard part is making sure your partition function is really bomb proof, check all “edge cases” (e.g., no particles in the cell, all particles on one side or other of the partition, already partitioned data, particles in the inverted order of the partition, etc…). Write boolean test functions for each of these cases.
# - Call all test functions in sequence and check if they all succeed.
# - Once you have this, then recursively partition the partitions and build cells linked into a tree as you go. Partition alternately in x and y dimensions, or simply partition the longest dimension of the given cell.
# - Create a random distribution of particles in 2D and build a tree from the particles.
# - Plot the particles and tree cells.

# %%
number_particles = 1000
particles = np.array([Particle([rng.random(), rng.random()]) for i in range(number_particles)])
cell = Cell([0,0], [1,1], 0, len(particles))

# %%
# V1: 1.74 ms ± 5.93 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# V2: 1.13 ms ± 2.89 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %timeit recursive_partitioning(particles, cell, 0)

# %%
plot_particles_color(particles)

# %%
particles, cell = recursive_partitioning(particles, cell, 0)

# %%
plot_particles_color(particles)

# %%
plot_particle_cells(particles, cell)
# Out:
# no ax

# %%
number_particles = 100
particles = np.array([Particle([rng.normal(scale=0.5), rng.normal(scale=0.5)]) for i in range(number_particles)])
cell = Cell([-2,-2], [2,2], 0, len(particles))

particles, cell = recursive_partitioning(particles, cell, 0)

# %%
plot_particle_cells(particles, cell)

# %%
for par in particles:
    print(par)
# Out:
# Particle:
# 	Location: [-0.9051066605434082, -0.30135968151511117]
# Particle:
# 	Location: [-0.6013482929505151, -0.1431830679325878]
# Particle:
# 	Location: [-0.5236435731919052, -0.39907667887741693]
# Particle:
# 	Location: [-0.5464476205493747, -0.7235022882075078]
# Particle:
# 	Location: [-0.8572429477480608, -0.35690974860935554]
# Particle:
# 	Location: [-0.6430650183543954, -0.01723743251731644]
# Particle:
# 	Location: [-0.703457082800931, -0.988874531183564]
# Particle:
# 	Location: [-0.38171965865533025, -0.689574625674294]
# Particle:
# 	Location: [-0.03489939288106894, -0.6667371593671005]
# Particle:
# 	Location: [-0.40226331511240676, -0.904072023435373]
# Particle:
# 	Location: [-0.320245035927713, -0.13544681353546867]
# Particle:
# 	Location: [-0.3471318811240344, -0.47133995726567024]
# Particle:
# 	Location: [-0.38360853426532016, -0.40314091034234206]
# Particle:
# 	Location: [-0.04430697262658365, -0.21522916673097905]
# Particle:
# 	Location: [-0.2339881566621462, -0.3146722421672522]
# Particle:
# 	Location: [-0.11806504588899278, -0.3671938786956505]
# Particle:
# 	Location: [-0.045770009709103936, -0.26541091406482364]
# Particle:
# 	Location: [-0.09800214892250793, -0.1710764453660236]
# Particle:
# 	Location: [-0.12603140770167814, -0.3929883039656777]
# Particle:
# 	Location: [-1.3009441575258445, 0.10270526348062999]
# Particle:
# 	Location: [-0.5122644564565032, 0.4540314217589927]
# Particle:
# 	Location: [-0.561478524553565, 0.3834336466645304]
# Particle:
# 	Location: [-0.6123523888252702, 0.5794747911884499]
# Particle:
# 	Location: [-0.5377861430715077, 0.11214865359079713]
# Particle:
# 	Location: [-0.5554655476078603, 0.594392057176937]
# Particle:
# 	Location: [-0.6801217187960872, 0.19536251304444804]
# Particle:
# 	Location: [-0.7359061756620928, 0.28257668940488473]
# Particle:
# 	Location: [-0.2618863892706177, 0.21114450956267977]
# Particle:
# 	Location: [-0.3301500580109945, 0.2909252196535393]
# Particle:
# 	Location: [-0.4575623297397506, 0.20363194686773425]
# Particle:
# 	Location: [-0.3949931769338015, 0.06496492708303693]
# Particle:
# 	Location: [-0.4971675542475597, 0.3302212832742185]
# Particle:
# 	Location: [-0.3329388555602182, 0.21700491172505348]
# Particle:
# 	Location: [-0.2930258199877793, 0.08216032969095799]
# Particle:
# 	Location: [-0.2802247344015378, 0.01552360024427712]
# Particle:
# 	Location: [-0.1984569206188958, 0.056874076743071725]
# Particle:
# 	Location: [-0.17576236757164657, 0.12446695519832895]
# Particle:
# 	Location: [-0.14493780773743492, 0.09919058031321977]
# Particle:
# 	Location: [-0.1533486439129686, 0.052345014944063004]
# Particle:
# 	Location: [-0.1296046296575416, 0.03134915161835712]
# Particle:
# 	Location: [-0.1307809505332009, 0.028248345996616346]
# Particle:
# 	Location: [-0.24673410457693787, 0.329742107125948]
# Particle:
# 	Location: [-0.08643554122171818, 0.4822753411196667]
# Particle:
# 	Location: [-0.01616855934760772, 0.2653469690123664]
# Particle:
# 	Location: [-0.23904152887691224, 0.6541233034399551]
# Particle:
# 	Location: [-0.005098057812523066, 0.7951094028108897]
# Particle:
# 	Location: [-0.25603070965956354, 0.7004409301564833]
# Particle:
# 	Location: [-0.16608426491950268, 1.3519925536396933]
# Particle:
# 	Location: [0.026876281495251012, -1.0780040030296896]
# Particle:
# 	Location: [0.12592720764750256, -0.7023957738051637]
# Particle:
# 	Location: [0.19352936469787194, -0.5768374581998803]
# Particle:
# 	Location: [0.312837785798077, -0.6322709959739571]
# Particle:
# 	Location: [0.3849284465276773, -0.9465855806190525]
# Particle:
# 	Location: [0.03383562903135477, -0.014008892447871967]
# Particle:
# 	Location: [0.16204461116002353, -0.399402872446491]
# Particle:
# 	Location: [0.19711882472101538, -0.3597407729892738]
# Particle:
# 	Location: [0.07964889191482029, -0.01404153755201599]
# Particle:
# 	Location: [0.02210850145009155, -0.4045629924705199]
# Particle:
# 	Location: [0.06368123782824281, -0.03175433721913436]
# Particle:
# 	Location: [0.18984379030699183, -0.15451118259812477]
# Particle:
# 	Location: [0.46828467792839396, -0.18218864644662092]
# Particle:
# 	Location: [0.3885364794954491, -0.04764289350696728]
# Particle:
# 	Location: [0.29155406782887155, -0.2464298844477797]
# Particle:
# 	Location: [0.3982720152599985, -0.11791712190709068]
# Particle:
# 	Location: [0.3859371461849142, -0.1398384155664465]
# Particle:
# 	Location: [0.3684182654600256, -0.23127785816229007]
# Particle:
# 	Location: [0.3657462039704673, -0.42337204644201004]
# Particle:
# 	Location: [0.498277442249202, -0.4968489385532416]
# Particle:
# 	Location: [0.5613391272818693, -0.047097287675416655]
# Particle:
# 	Location: [0.629557424667368, -0.04748265529633587]
# Particle:
# 	Location: [0.8482933414854253, -0.670178104010602]
# Particle:
# 	Location: [1.1070763078959556, -0.22597548992675426]
# Particle:
# 	Location: [1.1689225595860826, -0.18901964586573836]
# Particle:
# 	Location: [0.05376709002681721, 0.10754906790951804]
# Particle:
# 	Location: [0.09928931034075843, 0.24469196946920457]
# Particle:
# 	Location: [0.10569323752413377, 0.19522746602694113]
# Particle:
# 	Location: [0.24254693424855633, 0.11919418741871264]
# Particle:
# 	Location: [0.24433426223365357, 0.0853125392698964]
# Particle:
# 	Location: [0.23390989145482854, 0.09755198657144401]
# Particle:
# 	Location: [0.23830148366198994, 0.007340069944855644]
# Particle:
# 	Location: [0.2489614671346893, 0.05112832982370789]
# Particle:
# 	Location: [0.19600546868287835, 0.15191871281878142]
# Particle:
# 	Location: [0.14729642127918954, 0.4613198613939264]
# Particle:
# 	Location: [0.24817151717036576, 0.45561902228447343]
# Particle:
# 	Location: [0.3923443580658432, 0.43541138518331945]
# Particle:
# 	Location: [0.40938197517372094, 0.04729626647885008]
# Particle:
# 	Location: [0.3147020030511002, 0.06593690656057599]
# Particle:
# 	Location: [0.3862699037913804, 0.2775728409724155]
# Particle:
# 	Location: [0.42315203115386485, 0.1595474170117871]
# Particle:
# 	Location: [0.2726616309835302, 0.11583022211825873]
# Particle:
# 	Location: [0.4825852463643329, 0.04393381854036376]
# Particle:
# 	Location: [0.07922402524986748, 0.5112036126802361]
# Particle:
# 	Location: [0.10863657911431197, 0.7875414138043654]
# Particle:
# 	Location: [0.33001874589516744, 0.9582224383677052]
# Particle:
# 	Location: [0.8611799709978246, 0.1364312590128865]
# Particle:
# 	Location: [0.8885914201288622, 0.32939868418309637]
# Particle:
# 	Location: [0.5342310336221491, 0.04900095704969144]
# Particle:
# 	Location: [0.7717464280072767, 0.12832936535613085]
# Particle:
# 	Location: [0.09659078990659918, 1.103262653570201]
# Particle:
# 	Location: [1.4287192115699325, 0.18322557328577524]

# %%
cell.print_all_cells()
# Out:
# Cell:
# 	Location: ([-2, -2], [2, 2])
# 	Index: [0:100]
# Cell:
# 	Location: ([-2, -2], [0.0, 2])
# 	Index: [0:48]
# Cell:
# 	Location: ([-2, -2], [0.0, 0.0])
# 	Index: [0:19]
# Cell:
# 	Location: ([-2, -2], [-1.0, 0.0])
# 	Index: [0:0]
# Cell:
# 	Location: ([-1.0, -2], [0.0, 0.0])
# 	Index: [0:19]
# Cell:
# 	Location: ([-1.0, -2], [0.0, -1.0])
# 	Index: [0:0]
# Cell:
# 	Location: ([-1.0, -1.0], [0.0, 0.0])
# 	Index: [0:19]
# Cell:
# 	Location: ([-1.0, -1.0], [-0.5, 0.0])
# 	Index: [0:7]
# Cell:
# 	Location: ([-0.5, -1.0], [0.0, 0.0])
# 	Index: [7:19]
# Cell:
# 	Location: ([-0.5, -1.0], [0.0, -0.5])
# 	Index: [7:10]
# Cell:
# 	Location: ([-0.5, -0.5], [0.0, 0.0])
# 	Index: [10:19]
# Cell:
# 	Location: ([-0.5, -0.5], [-0.25, 0.0])
# 	Index: [10:13]
# Cell:
# 	Location: ([-0.25, -0.5], [0.0, 0.0])
# 	Index: [13:19]
# Cell:
# 	Location: ([-2, 0.0], [0.0, 2])
# 	Index: [19:48]
# Cell:
# 	Location: ([-2, 0.0], [-1.0, 2])
# 	Index: [19:20]
# Cell:
# 	Location: ([-1.0, 0.0], [0.0, 2])
# 	Index: [20:48]
# Cell:
# 	Location: ([-1.0, 0.0], [0.0, 1.0])
# 	Index: [20:47]
# Cell:
# 	Location: ([-1.0, 0.0], [-0.5, 1.0])
# 	Index: [20:27]
# Cell:
# 	Location: ([-0.5, 0.0], [0.0, 1.0])
# 	Index: [27:47]
# Cell:
# 	Location: ([-0.5, 0.0], [0.0, 0.5])
# 	Index: [27:44]
# Cell:
# 	Location: ([-0.5, 0.0], [-0.25, 0.5])
# 	Index: [27:35]
# Cell:
# 	Location: ([-0.25, 0.0], [0.0, 0.5])
# 	Index: [35:44]
# Cell:
# 	Location: ([-0.25, 0.0], [0.0, 0.25])
# 	Index: [35:41]
# Cell:
# 	Location: ([-0.25, 0.25], [0.0, 0.5])
# 	Index: [41:44]
# Cell:
# 	Location: ([-0.5, 0.5], [0.0, 1.0])
# 	Index: [44:47]
# Cell:
# 	Location: ([-1.0, 1.0], [0.0, 2])
# 	Index: [47:48]
# Cell:
# 	Location: ([0.0, -2], [2, 2])
# 	Index: [48:100]
# Cell:
# 	Location: ([0.0, -2], [2, 0.0])
# 	Index: [48:73]
# Cell:
# 	Location: ([0.0, -2], [1.0, 0.0])
# 	Index: [48:71]
# Cell:
# 	Location: ([0.0, -2], [1.0, -1.0])
# 	Index: [48:49]
# Cell:
# 	Location: ([0.0, -1.0], [1.0, 0.0])
# 	Index: [49:71]
# Cell:
# 	Location: ([0.0, -1.0], [0.5, 0.0])
# 	Index: [49:68]
# Cell:
# 	Location: ([0.0, -1.0], [0.5, -0.5])
# 	Index: [49:53]
# Cell:
# 	Location: ([0.0, -0.5], [0.5, 0.0])
# 	Index: [53:68]
# Cell:
# 	Location: ([0.0, -0.5], [0.25, 0.0])
# 	Index: [53:60]
# Cell:
# 	Location: ([0.25, -0.5], [0.5, 0.0])
# 	Index: [60:68]
# Cell:
# 	Location: ([0.5, -1.0], [1.0, 0.0])
# 	Index: [68:71]
# Cell:
# 	Location: ([1.0, -2], [2, 0.0])
# 	Index: [71:73]
# Cell:
# 	Location: ([0.0, 0.0], [2, 2])
# 	Index: [73:100]
# Cell:
# 	Location: ([0.0, 0.0], [1.0, 2])
# 	Index: [73:99]
# Cell:
# 	Location: ([0.0, 0.0], [1.0, 1.0])
# 	Index: [73:98]
# Cell:
# 	Location: ([0.0, 0.0], [0.5, 1.0])
# 	Index: [73:94]
# Cell:
# 	Location: ([0.0, 0.0], [0.5, 0.5])
# 	Index: [73:91]
# Cell:
# 	Location: ([0.0, 0.0], [0.25, 0.5])
# 	Index: [73:84]
# Cell:
# 	Location: ([0.0, 0.0], [0.25, 0.25])
# 	Index: [73:82]
# Cell:
# 	Location: ([0.0, 0.0], [0.125, 0.25])
# 	Index: [73:76]
# Cell:
# 	Location: ([0.125, 0.0], [0.25, 0.25])
# 	Index: [76:82]
# Cell:
# 	Location: ([0.0, 0.25], [0.25, 0.5])
# 	Index: [82:84]
# Cell:
# 	Location: ([0.25, 0.0], [0.5, 0.5])
# 	Index: [84:91]
# Cell:
# 	Location: ([0.0, 0.5], [0.5, 1.0])
# 	Index: [91:94]
# Cell:
# 	Location: ([0.5, 0.0], [1.0, 1.0])
# 	Index: [94:98]
# Cell:
# 	Location: ([0.0, 1.0], [1.0, 2])
# 	Index: [98:99]
# Cell:
# 	Location: ([1.0, 0.0], [2, 2])
# 	Index: [99:100]
